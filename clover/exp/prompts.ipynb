# %%
import gc
# import torch

gc.collect()
# torch.cuda.empty_cache()
# torch.cuda.ipc_collect()

import os
os.listdir(); os.chdir("/aiau010_scratch/azm0269/clover/")

from clover.utils.utils import notebook_line_magic
notebook_line_magic()

# %%
from clover.utils.prompts import get_prompts

B2_FULL_TRAIN_PROMPTS, B2_FULL_EVAL_PROMPTS = get_prompts()
# Out:
# /aiau010_scratch/azm0269/clover
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 3
#       1 from clover.utils.prompts import get_prompts
#       2
# ----> 3 B2_FULL_TRAIN_PROMPTS, B2_FULL_EVAL_PROMPTS, prompt_df = get_prompts()
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
prompt_df.pivot_table(
    index="template",
    columns="split",
    aggfunc="count"
)
# Out:
#          prompt
# split      eval train
# template
# 1            45    90
# 2            10    30
# 3            10    30
